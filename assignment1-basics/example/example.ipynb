# %%
import regex as re
import os
import itertools
import sys
with open('.\example.txt', "rb") as f:
    text = f.read().decode('utf-8')
    special_tokens = ["<|endoftext|>", "<|unk|>", "<|mask|>"]
    pattern = "|".join(re.escape(token) for token in special_tokens)
    # print(pattern)
    text = re.split(pattern, text)

    PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

    iter_list = [re.finditer(PAT, t) for t in text]

        
    iter = itertools.chain(*iter_list)
    token_freqs = dict[list[bytes], int]()
    for i in iter:
        i = i.group().encode("utf-8")
        i = tuple([bytes([b]) for b in i])
        
        print(i)




print(sys.getsizeof(1.0))
print(sys.getsizeof(b'1'))
# Out:
# (b'u',)
# (b' ', b'd', b'o', b'n')
# (b"'", b't')
# (b' ', b'h', b'a', b'v', b'e')
# (b' ', b't', b'o')
# (b' ', b'b', b'e')
# (b' ', b's', b'c', b'a', b'r', b'e', b'd')
# (b' ', b'o', b'f')
# (b' ', b't', b'h', b'e')
# (b' ', b'l', b'o', b'u', b'd')
# (b' ', b'd', b'o', b'g')
# (b',',)
# (b' ', b'I')
# (b"'", b'l', b'l')
# (b' ', b'p', b'r', b'o', b't', b'e', b'c', b't')
# (b' ', b'y', b'o', b'u')
# (b'"', b'.')
# (b' ', b'T', b'h', b'e')
# (b' ', b'm', b'o', b'l', b'e')
# (b' ', b'f', b'e', b'l', b't')
# (b' ', b's', b'o')
# (b' ', b's', b'a', b'f', b'e')
# (b' ', b'w', b'i', b't', b'h')
# (b' ', b't', b'h', b'e')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b'.',)
# (b' ', b'S', b'h', b'e')
# (b' ', b'w', b'a', b's')
# (b' ', b'v', b'e', b'r', b'y')
# (b' ', b'k', b'i', b'n', b'd')
# (b' ', b'a', b'n', b'd')
# (b' ', b't', b'h', b'e')
# (b' ', b'm', b'o', b'l', b'e')
# (b' ', b's', b'o', b'o', b'n')
# (b' ', b'c', b'a', b'm', b'e')
# (b' ', b't', b'o')
# (b' ', b't', b'r', b'u', b's', b't')
# (b' ', b'h', b'e', b'r')
# (b'.',)
# (b' ', b'H', b'e')
# (b' ', b'l', b'e', b'a', b'n', b'e', b'd')
# (b' ', b'a', b'g', b'a', b'i', b'n', b's', b't')
# (b' ', b'h', b'e', b'r')
# (b' ', b'a', b'n', b'd')
# (b' ', b's', b'h', b'e')
# (b' ', b'k', b'e', b'p', b't')
# (b' ', b'h', b'i', b'm')
# (b' ', b's', b'a', b'f', b'e')
# (b'.',)
# (b' ', b'T', b'h', b'e')
# (b' ', b'm', b'o', b'l', b'e')
# (b' ', b'h', b'a', b'd')
# (b' ', b'f', b'o', b'u', b'n', b'd')
# (b' ', b'h', b'i', b's')
# (b' ', b'b', b'e', b's', b't')
# (b' ', b'f', b'r', b'i', b'e', b'n', b'd')
# (b'.',)
# (b'\r', b'\n')
# (b'\r',)
# (b'\n',)
# (b'O', b'n', b'c', b'e')
# (b' ', b'u', b'p', b'o', b'n')
# (b' ', b'a')
# (b' ', b't', b'i', b'm', b'e')
# (b',',)
# (b' ', b'i', b'n')
# (b' ', b'a')
# (b' ', b'w', b'a', b'r', b'm')
# (b' ', b'a', b'n', b'd')
# (b' ', b's', b'u', b'n', b'n', b'y')
# (b' ', b'p', b'l', b'a', b'c', b'e')
# (b',',)
# (b' ', b't', b'h', b'e', b'r', b'e')
# (b' ', b'w', b'a', b's')
# (b' ', b'a')
# (b' ', b'b', b'i', b'g')
# (b' ', b'p', b'i', b't')
# (b'.',)
# (b' ', b'A')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'b', b'o', b'y')
# (b' ', b'n', b'a', b'm', b'e', b'd')
# (b' ', b'T', b'o', b'm')
# (b' ', b'l', b'i', b'k', b'e', b'd')
# (b' ', b't', b'o')
# (b' ', b'p', b'l', b'a', b'y')
# (b' ', b'n', b'e', b'a', b'r')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b'.',)
# (b' ', b'O', b'n', b'e')
# (b' ', b'd', b'a', b'y')
# (b',',)
# (b' ', b'T', b'o', b'm')
# (b' ', b'l', b'o', b's', b't')
# (b' ', b'h', b'i', b's')
# (b' ', b'r', b'e', b'd')
# (b' ', b'b', b'a', b'l', b'l')
# (b'.',)
# (b' ', b'H', b'e')
# (b' ', b'w', b'a', b's')
# (b' ', b'v', b'e', b'r', b'y')
# (b' ', b's', b'a', b'd')
# (b'.',)
# (b'\r',)
# (b'\n',)
# (b'T', b'o', b'm')
# (b' ', b'a', b's', b'k', b'e', b'd')
# (b' ', b'h', b'i', b's')
# (b' ', b'f', b'r', b'i', b'e', b'n', b'd')
# (b',',)
# (b' ', b'S', b'a', b'm')
# (b',',)
# (b' ', b't', b'o')
# (b' ', b'h', b'e', b'l', b'p')
# (b' ', b'h', b'i', b'm')
# (b' ', b's', b'e', b'a', b'r', b'c', b'h')
# (b' ', b'f', b'o', b'r')
# (b' ', b't', b'h', b'e')
# (b' ', b'b', b'a', b'l', b'l')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'l', b'o', b'o', b'k', b'e', b'd')
# (b' ', b'h', b'i', b'g', b'h')
# (b' ', b'a', b'n', b'd')
# (b' ', b'l', b'o', b'w')
# (b',',)
# (b' ', b'b', b'u', b't')
# (b' ', b't', b'h', b'e', b'y')
# (b' ', b'c', b'o', b'u', b'l', b'd')
# (b' ', b'n', b'o', b't')
# (b' ', b'f', b'i', b'n', b'd')
# (b' ', b't', b'h', b'e')
# (b' ', b'b', b'a', b'l', b'l')
# (b'.',)
# (b' ', b'T', b'o', b'm')
# (b' ', b's', b'a', b'i', b'd')
# (b',',)
# (b' ', b'"')
# (b'I',)
# (b' ', b't', b'h', b'i', b'n', b'k')
# (b' ', b'm', b'y')
# (b' ', b'b', b'a', b'l', b'l')
# (b' ', b'f', b'e', b'l', b'l')
# (b' ', b'i', b'n', b't', b'o')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b'.', b'"')
# (b'\r',)
# (b'\n',)
# (b'S', b'a', b'm')
# (b' ', b'a', b'n', b'd')
# (b' ', b'T', b'o', b'm')
# (b' ', b'w', b'e', b'n', b't')
# (b' ', b'c', b'l', b'o', b's', b'e')
# (b' ', b't', b'o')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'w', b'e', b'r', b'e')
# (b' ', b's', b'c', b'a', b'r', b'e', b'd')
# (b',',)
# (b' ', b'b', b'u', b't')
# (b' ', b't', b'h', b'e', b'y')
# (b' ', b'w', b'a', b'n', b't', b'e', b'd')
# (b' ', b't', b'o')
# (b' ', b'f', b'i', b'n', b'd')
# (b' ', b't', b'h', b'e')
# (b' ', b'r', b'e', b'd')
# (b' ', b'b', b'a', b'l', b'l')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'l', b'o', b'o', b'k', b'e', b'd')
# (b' ', b'i', b'n', b't', b'o')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b',',)
# (b' ', b'b', b'u', b't')
# (b' ', b'i', b't')
# (b' ', b'w', b'a', b's')
# (b' ', b't', b'o', b'o')
# (b' ', b'd', b'a', b'r', b'k')
# (b' ', b't', b'o')
# (b' ', b's', b'e', b'e')
# (b'.',)
# (b' ', b'T', b'o', b'm')
# (b' ', b's', b'a', b'i', b'd')
# (b',',)
# (b' ', b'"')
# (b'W', b'e')
# (b' ', b'm', b'u', b's', b't')
# (b' ', b'g', b'o')
# (b' ', b'i', b'n')
# (b' ', b'a', b'n', b'd')
# (b' ', b's', b'e', b'a', b'r', b'c', b'h')
# (b' ', b'f', b'o', b'r')
# (b' ', b'm', b'y')
# (b' ', b'b', b'a', b'l', b'l')
# (b'.', b'"')
# (b'\r',)
# (b'\n',)
# (b'T', b'h', b'e', b'y')
# (b' ', b'w', b'e', b'n', b't')
# (b' ', b'i', b'n', b't', b'o')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b' ', b't', b'o')
# (b' ', b's', b'e', b'a', b'r', b'c', b'h')
# (b'.',)
# (b' ', b'I', b't')
# (b' ', b'w', b'a', b's')
# (b' ', b'd', b'a', b'r', b'k')
# (b' ', b'a', b'n', b'd')
# (b' ', b's', b'c', b'a', b'r', b'y')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'c', b'o', b'u', b'l', b'd')
# (b' ', b'n', b'o', b't')
# (b' ', b'f', b'i', b'n', b'd')
# (b' ', b't', b'h', b'e')
# (b' ', b'b', b'a', b'l', b'l')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b't', b'r', b'i', b'e', b'd')
# (b' ', b't', b'o')
# (b' ', b'g', b'e', b't')
# (b' ', b'o', b'u', b't')
# (b',',)
# (b' ', b'b', b'u', b't')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b' ', b'w', b'a', b's')
# (b' ', b't', b'o', b'o')
# (b' ', b'd', b'e', b'e', b'p')
# (b'.',)
# (b' ', b'T', b'o', b'm')
# (b' ', b'a', b'n', b'd')
# (b' ', b'S', b'a', b'm')
# (b' ', b'w', b'e', b'r', b'e')
# (b' ', b's', b't', b'u', b'c', b'k')
# (b' ', b'i', b'n')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'c', b'a', b'l', b'l', b'e', b'd')
# (b' ', b'f', b'o', b'r')
# (b' ', b'h', b'e', b'l', b'p')
# (b',',)
# (b' ', b'b', b'u', b't')
# (b' ', b'n', b'o')
# (b' ', b'o', b'n', b'e')
# (b' ', b'c', b'o', b'u', b'l', b'd')
# (b' ', b'h', b'e', b'a', b'r')
# (b' ', b't', b'h', b'e', b'm')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'w', b'e', b'r', b'e')
# (b' ', b's', b'a', b'd')
# (b' ', b'a', b'n', b'd')
# (b' ', b's', b'c', b'a', b'r', b'e', b'd')
# (b',',)
# (b' ', b'a', b'n', b'd')
# (b' ', b't', b'h', b'e', b'y')
# (b' ', b'n', b'e', b'v', b'e', b'r')
# (b' ', b'g', b'o', b't')
# (b' ', b'o', b'u', b't')
# (b' ', b'o', b'f')
# (b' ', b't', b'h', b'e')
# (b' ', b'p', b'i', b't')
# (b'.',)
# (b'\r', b'\n')
# (b'\r',)
# (b'\n',)
# (b'O', b'n', b'c', b'e')
# (b' ', b'u', b'p', b'o', b'n')
# (b' ', b'a')
# (b' ', b't', b'i', b'm', b'e')
# (b' ', b't', b'h', b'e', b'r', b'e')
# (b' ', b'w', b'a', b's')
# (b' ', b'a')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b' ', b'n', b'a', b'm', b'e', b'd')
# (b' ', b'L', b'u', b'c', b'y')
# (b'.',)
# (b' ', b'S', b'h', b'e')
# (b' ', b'l', b'o', b'v', b'e', b'd')
# (b' ', b't', b'o')
# (b' ', b'g', b'o')
# (b' ', b't', b'o')
# (b' ', b't', b'h', b'e')
# (b' ', b's', b't', b'o', b'r', b'e')
# (b' ', b't', b'o')
# (b' ', b'b', b'u', b'y')
# (b' ', b's', b'w', b'e', b'e', b't', b's')
# (b' ', b'w', b'i', b't', b'h')
# (b' ', b'h', b'e', b'r')
# (b' ', b'm', b'o', b'm')
# (b' ', b'a', b'n', b'd')
# (b' ', b'd', b'a', b'd')
# (b'.',)
# (b' ', b'O', b'n')
# (b' ', b't', b'h', b'i', b's')
# (b' ', b's', b'p', b'e', b'c', b'i', b'a', b'l')
# (b' ', b'd', b'a', b'y')
# (b',',)
# (b' ', b'L', b'u', b'c', b'y')
# (b' ', b'e', b'n', b't', b'e', b'r', b'e', b'd')
# (b' ', b't', b'h', b'e')
# (b' ', b's', b't', b'o', b'r', b'e')
# (b' ', b'w', b'i', b't', b'h')
# (b' ', b'h', b'e', b'r')
# (b' ', b'm', b'o', b'm')
# (b' ', b'a', b'n', b'd')
# (b' ', b'd', b'a', b'd')
# (b',',)
# (b' ', b'f', b'e', b'e', b'l', b'i', b'n', b'g')
# (b' ', b's', b'o')
# (b' ', b'e', b'x', b'c', b'i', b't', b'e', b'd')
# (b'.',)
# (b'\r',)
# (b'\n',)
# (b'A', b's')
# (b' ', b't', b'h', b'e', b'y')
# (b' ', b'w', b'e', b'r', b'e')
# (b' ', b'l', b'o', b'o', b'k', b'i', b'n', b'g')
# (b' ', b'a', b'r', b'o', b'u', b'n', b'd')
# (b',',)
# (b' ', b'L', b'u', b'c', b'y')
# (b' ', b'n', b'o', b't', b'i', b'c', b'e', b'd')
# (b' ', b'a')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b' ', b'p', b'l', b'a', b'y', b'i', b'n', b'g')
# (b' ', b'w', b'i', b't', b'h')
# (b' ', b'a')
# (b' ', b't', b'o', b'y')
# (b' ', b'i', b'n')
# (b' ', b't', b'h', b'e')
# (b' ', b'c', b'o', b'r', b'n', b'e', b'r')
# (b' ', b'o', b'f')
# (b' ', b't', b'h', b'e')
# (b' ', b's', b't', b'o', b'r', b'e')
# (b'.',)
# (b' ', b'S', b'h', b'e')
# (b' ', b'g', b'a', b's', b'p', b'e', b'd')
# (b' ', b'i', b'n')
# (b' ', b'e', b'x', b'c', b'i', b't', b'e', b'm', b'e', b'n', b't')
# (b' ', b'a', b'n', b'd')
# (b' ', b'r', b'a', b'n')
# (b' ', b't', b'o', b'w', b'a', b'r', b'd', b's')
# (b' ', b'h', b'e', b'r')
# (b'.',)
# (b' ', b'L', b'u', b'c', b'y')
# (b' ', b'a', b's', b'k', b'e', b'd')
# (b' ', b'i', b'f')
# (b' ', b's', b'h', b'e')
# (b' ', b'c', b'o', b'u', b'l', b'd')
# (b' ', b'p', b'l', b'a', b'y')
# (b' ', b't', b'o', b'o')
# (b' ', b'b', b'u', b't')
# (b' ', b't', b'h', b'e')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b' ', b's', b'a', b'i', b'd')
# (b' ', b'n', b'o')
# (b'.',)
# (b' ', b'S', b'h', b'e')
# (b' ', b'w', b'a', b's')
# (b' ', b'r', b'a', b't', b'h', b'e', b'r')
# (b' ', b'g', b'r', b'u', b'm', b'p', b'y')
# (b' ', b'a', b'n', b'd')
# (b' ', b'w', b'a', b's')
# (b' ', b'n', b'o', b't')
# (b' ', b'i', b'n')
# (b' ', b't', b'h', b'e')
# (b' ', b'm', b'o', b'o', b'd')
# (b' ', b't', b'o')
# (b' ', b'p', b'l', b'a', b'y')
# (b'.',)
# (b'\r',)
# (b'\n',)
# (b'L', b'u', b'c', b'y')
# (b"'", b's')
# (b' ', b'm', b'o', b'm')
# (b' ', b's', b'a', b'w')
# (b' ', b'w', b'h', b'a', b't')
# (b' ', b'w', b'a', b's')
# (b' ', b'g', b'o', b'i', b'n', b'g')
# (b' ', b'o', b'n')
# (b' ', b'a', b'n', b'd')
# (b' ', b't', b'o', b'l', b'd')
# (b' ', b'L', b'u', b'c', b'y')
# (b',',)
# (b' ', b'"')
# (b'L', b'e', b't')
# (b"'", b's')
# (b' ', b't', b'r', b'y')
# (b' ', b't', b'o')
# (b' ', b'b', b'e')
# (b' ', b'p', b'e', b'a', b'c', b'e', b'f', b'u', b'l')
# (b' ', b'a', b'n', b'd')
# (b' ', b'k', b'i', b'n', b'd')
# (b' ', b't', b'o')
# (b' ', b'h', b'e', b'r')
# (b'.',)
# (b' ', b'H', b'a', b'v', b'e')
# (b' ', b'p', b'a', b't', b'i', b'e', b'n', b'c', b'e')
# (b' ', b'a', b'n', b'd')
# (b' ', b'u', b'n', b'd', b'e', b'r', b's', b't', b'a', b'n', b'd', b'i', b'n', b'g')
# (b'.',)
# (b' ', b'T', b'o', b'g', b'e', b't', b'h', b'e', b'r')
# (b',',)
# (b' ', b'y', b'o', b'u')
# (b' ', b'c', b'a', b'n')
# (b' ', b'b', b'o', b't', b'h')
# (b' ', b'b', b'e')
# (b' ', b'h', b'a', b'p', b'p', b'y')
# (b'!', b'"')
# (b'\r',)
# (b'\n',)
# (b'S', b'o')
# (b',',)
# (b' ', b'L', b'u', b'c', b'y')
# (b' ', b's', b'm', b'i', b'l', b'e', b'd')
# (b' ', b'a', b't')
# (b' ', b't', b'h', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b' ', b'a', b'n', b'd')
# (b' ', b's', b'a', b'i', b'd')
# (b',',)
# (b' ', b'"')
# (b'C', b'a', b'n')
# (b' ', b'w', b'e')
# (b' ', b'p', b'l', b'a', b'y')
# (b' ', b't', b'o', b'g', b'e', b't', b'h', b'e', b'r')
# (b'?', b'"')
# (b' ', b'T', b'h', b'e')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b' ', b's', b'o', b'f', b't', b'e', b'n', b'e', b'd')
# (b' ', b'a', b'n', b'd')
# (b' ', b's', b'm', b'i', b'l', b'e', b'd')
# (b' ', b'b', b'a', b'c', b'k')
# (b'.',)
# (b' ', b'S', b'h', b'e')
# (b' ', b'a', b'g', b'r', b'e', b'e', b'd')
# (b' ', b't', b'o')
# (b' ', b's', b'h', b'a', b'r', b'e')
# (b' ', b't', b'h', b'e')
# (b' ', b't', b'o', b'y')
# (b' ', b'a', b'n', b'd')
# (b' ', b'e', b'v', b'e', b'n')
# (b' ', b'l', b'e', b't')
# (b' ', b'L', b'u', b'c', b'y')
# (b' ', b'h', b'a', b'v', b'e')
# (b' ', b'a')
# (b' ', b't', b'u', b'r', b'n')
# (b' ', b'f', b'i', b'r', b's', b't')
# (b'.',)
# (b'\r',)
# (b'\n',)
# (b'L', b'u', b'c', b'y')
# (b' ', b'a', b'n', b'd')
# (b' ', b't', b'h', b'e')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b' ', b'p', b'l', b'a', b'y', b'e', b'd')
# (b' ', b't', b'o', b'g', b'e', b't', b'h', b'e', b'r')
# (b' ', b'h', b'a', b'p', b'p', b'i', b'l', b'y')
# (b'.',)
# (b' ', b'I', b'n')
# (b' ', b't', b'h', b'e')
# (b' ', b'e', b'n', b'd')
# (b',',)
# (b' ', b't', b'h', b'e', b'y')
# (b' ', b'b', b'o', b't', b'h')
# (b' ', b'l', b'e', b'a', b'r', b'n', b't')
# (b' ', b'a', b'n')
# (b' ', b'i', b'm', b'p', b'o', b'r', b't', b'a', b'n', b't')
# (b' ', b'l', b'e', b's', b's', b'o', b'n')
# (b':',)
# (b' ', b'b', b'e')
# (b' ', b'p', b'e', b'a', b'c', b'e', b'f', b'u', b'l')
# (b',',)
# (b' ', b'k', b'i', b'n', b'd')
# (b',',)
# (b' ', b'a', b'n', b'd')
# (b' ', b'u', b'n', b'd', b'e', b'r', b's', b't', b'a', b'n', b'd', b'i', b'n', b'g')
# (b' ', b'w', b'h', b'e', b'n')
# (b' ', b'f', b'a', b'c', b'e', b'd')
# (b' ', b'w', b'i', b't', b'h')
# (b' ', b'a')
# (b' ', b'c', b'o', b'n', b'f', b'l', b'i', b'c', b't')
# (b'.',)
# (b' ', b'A', b'n', b'd')
# (b' ', b't', b'h', b'a', b't')
# (b' ', b'i', b's')
# (b' ', b'w', b'h', b'y')
# (b' ', b'L', b'u', b'c', b'y')
# (b' ', b'a', b'n', b'd')
# (b' ', b't', b'h', b'e')
# (b' ', b'l', b'i', b't', b't', b'l', b'e')
# (b' ', b'g', b'i', b'r', b'l')
# (b' ', b'b', b'e', b'c', b'a', b'm', b'e')
# (b' ', b'g', b'r', b'e', b'a', b't')
# (b' ', b'f', b'r', b'i', b'e', b'n', b'd', b's')
# (b'.',)
# (b'\r', b'\n')
# (b'\r',)
# (b'\n',)
# (b'O', b'n', b'e')
# (b' ', b'm', b'o', b'r', b'n', b'i', b'n', b'g')
# (b',',)
# (b' ', b'a')
# (b' ', b'c', b'a', b't')
# (b' ', b'n', b'a', b'm', b'e', b'd')
# (b' ', b'T', b'o', b'm')
# (b' ', b'w', b'o', b'k', b'e')
# (b' ', b'u', b'p')
# (b'.',)
# (b' ', b'H', b'e')
# (b' ', b'f', b'e', b'l', b't')
# (b' ', b'h', b'a', b'p', b'p', b'y')
# (b' ', b'b', b'e', b'c', b'a', b'u', b's', b'e')
# (b' ', b't', b'h', b'e')
# (b' ', b's', b'u', b'n')
# (b' ', b'w', b'a', b's')
# (b' ', b's', b'h', b'i', b'n', b'i', b'n', b'g')
# (b'.',)
# (b' ', b'T', b'o', b'm')
# (b' ', b'w', b'a', b'n', b't', b'e', b'd')
# (b' ', b't', b'o')
# (b' ', b's', b't', b'a', b'r', b't')
# (b' ', b'h', b'i', b's')
# (b' ', b'd', b'a', b'y')
# (b',',)
# (b' ', b's', b'o')
# (b' ', b'h', b'e')
# (b' ', b'd', b'i', b'd')
# (b' ', b'a')
# (b' ', b'b', b'i', b'g')
# (b' ', b's', b't', b'r', b'e', b't', b'c', b'h')
# (b'.',)
# (b' ', b'H', b'e')
# (b' ', b's', b't', b'r', b'e', b't', b'c', b'h', b'e', b'd')
# (b' ', b'h', b'i', b's')
# (b' ', b'l', b'e', b'g', b's')
# (b',',)
# (b' ', b'h', b'i', b's')
# (b' ', b'b', b'a', b'c', b'k')
# (b',',)
# (b' ', b'a', b'n', b'd')
# (b' ', b'h', b'i', b's')
# (b' ', b't', b'a', b'i', b'l')
# (b'.',)
# (b' ', b'I', b't')
# (b' ', b'f', b'e', b'l', b't')
# (b' ', b'e', b'a', b's', b'y')
# (b' ', b'a', b'n', b'd')
# (b' ', b'g', b'o', b'o', b'd')
# (b'.',)
# (b'\r',)
# (b'\n',)
# (b'T', b'o', b'm')
# (b' ', b'w', b'e', b'n', b't')
# (b' ', b'o', b'u', b't', b's', b'i', b'd', b'e')
# (b' ', b't', b'o')
# (b' ', b'p', b'l', b'a', b'y')
# (b'.',)
# (b' ', b'H', b'e')
# (b' ', b's', b'a', b'w')
# (b' ', b'h', b'i', b's')
# (b' ', b'f', b'r', b'i', b'e', b'n', b'd')
# (b',',)
# (b' ', b'a')
# (b' ', b'd', b'o', b'g')
# (b' ', b'n', b'a', b'm', b'e', b'd')
# (b' ', b'M', b'a', b'x')
# (b'.',)
# (b' ', b'M', b'a', b'x')
# (b' ', b'w', b'a', b's')
# (b' ', b'a', b'l', b's', b'o')
# (b' ', b's', b't', b'r', b'e', b't', b'c', b'h', b'i', b'n', b'g')
# (b' ', b'i', b'n')
# (b' ', b't', b'h', b'e')
# (b' ', b'm', b'o', b'r', b'n', b'i', b'n', b'g')
# (b' ', b's', b'u', b'n')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'b', b'o', b't', b'h')
# (b' ', b'f', b'e', b'l', b't')
# (b' ', b'v', b'e', b'r', b'y')
# (b' ', b'h', b'a', b'p', b'p', b'y')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'd', b'e', b'c', b'i', b'd', b'e', b'd')
# (b' ', b't', b'o')
# (b' ', b'p', b'l', b'a', b'y')
# (b' ', b't', b'o', b'g', b'e', b't', b'h', b'e', b'r')
# (b' ', b'a', b'n', b'd')
# (b' ', b'h', b'a', b'v', b'e')
# (b' ', b'f', b'u', b'n')
# (b' ', b'a', b'l', b'l')
# (b' ', b'd', b'a', b'y')
# (b'.',)
# (b'\r',)
# (b'\n',)
# (b'A', b't')
# (b' ', b't', b'h', b'e')
# (b' ', b'e', b'n', b'd')
# (b' ', b'o', b'f')
# (b' ', b't', b'h', b'e')
# (b' ', b'd', b'a', b'y')
# (b',',)
# (b' ', b'T', b'o', b'm')
# (b' ', b'a', b'n', b'd')
# (b' ', b'M', b'a', b'x')
# (b' ', b'w', b'e', b'r', b'e')
# (b' ', b't', b'i', b'r', b'e', b'd')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b'h', b'a', b'd')
# (b' ', b'p', b'l', b'a', b'y', b'e', b'd')
# (b' ', b'a', b'l', b'l')
# (b' ', b'd', b'a', b'y')
# (b' ', b'a', b'n', b'd')
# (b' ', b'h', b'a', b'd')
# (b' ', b'l', b'o', b't', b's')
# (b' ', b'o', b'f')
# (b' ', b'f', b'u', b'n')
# (b'.',)
# (b' ', b'T', b'h', b'e', b'y')
# (b' ', b's', b'a', b'i', b'd')
# (b' ', b'g', b'o', b'o', b'd', b'b', b'y', b'e')
# (b' ', b't', b'o')
# (b' ', b'e', b'a', b'c', b'h')
# (b' ', b'o', b't', b'h', b'e', b'r')
# (b' ', b'a', b'n', b'd')
# (b' ', b'w', b'e', b'n', b't')
# (b' ', b't', b'o')
# (b' ', b't', b'h', b'e', b'i', b'r')
# (b' ', b'h', b'o', b'm', b'e', b's')
# (b'.',)
# (b' ', b'B', b'e', b'f', b'o', b'r', b'e')
# (b' ', b'g', b'o', b'i', b'n', b'g')
# (b' ', b't', b'o')
# (b' ', b's', b'l', b'e', b'e', b'p')
# (b',',)
# (b' ', b't', b'h', b'e', b'y')
# (b' ', b'b', b'o', b't', b'h')
# (b' ', b'd', b'i', b'd')
# (b' ', b'a', b'n', b'o', b't', b'h', b'e', b'r')
# (b' ', b'e', b'a', b's', b'y')
# (b' ', b's', b't', b'r', b'e', b't', b'c', b'h')
# (b'.',)
# (b' ', b'T', b'o', b'm')
# (b' ', b'k', b'n', b'e', b'w')
# (b' ', b't', b'h', b'a', b't')
# (b' ', b't', b'o', b'm', b'o', b'r', b'r', b'o', b'w')
# (b' ', b'w', b'o', b'u', b'l', b'd')
# (b' ', b'b', b'e')
# (b' ', b'a', b'n', b'o', b't', b'h', b'e', b'r')
# (b' ', b'h', b'a', b'p', b'p', b'y')
# (b' ', b'm', b'o', b'r', b'n', b'i', b'n', b'g')
# (b'.',)
# (b'\r', b'\n')
# 24
# 34

# %%
s = b'abc'
print(type([bytes([i]) for i in s]))
# Out:
# <class 'list'>

# %%
for i in range(3):
    i = i+4
    print(i)
# Out:
# 4
# 5
# 6

# %%
a = (1,2,3)
b = (1,2,4)
c = {a:1, b:2}
d = (1,2,3)
print(type(d))
print(d in c)
e = tuple([1])
print(type(e))
for pair in zip(e,e[1:]):
    print(pair)
    print(type(pair))
print(a+b)
# Out:
# <class 'tuple'>
# True
# <class 'tuple'>
# (1, 2, 3, 1, 2, 4)

# %%
print(len(tuple([1,2,3,4])))
a = tuple([b'a',b'b'])
print(type(a))
print(a[0]+a[1])
print((b'c', a))
# Out:
# 4
# <class 'tuple'>
# b'ab'
# (b'c', (b'a', b'b'))
